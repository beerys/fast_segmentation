# %%
import matplotlib.pyplot as plt
import os
from PIL import Image
import numpy
plt.rcParams["figure.figsize"] = (15,15)

# %%
mask_path = 'data/masks/'

# %%
os.listdir(mask_path)
# Out:
# ['RGB_05-06-02-02-BON-FEL_mask.tif',
#  '16_pre_imagery_cropped_mask.tif',
#  '16_pre_imagery_cropped_large_mask_buffered.tif',
#  'RGB_05-06-02-02-BON-FEL_mask_no_shift.tif',
#  '.gitkeep',
#  '16_pre_imagery_cropped_mask_background_buffered.tif',
#  '16_pre_imagery_cropped_mask_buffered.tif']

# %%
mask = mask_path + '16_pre_imagery_cropped_mask_background_buffered.tif' #'RGB_05-06-02-02-BON-FEL_mask.tif'

# %%
im = Image.open(mask)
imarray = numpy.array(im)

# %%
plt.imshow(imarray)
plt.xticks([])
plt.yticks([])
plt.show()
